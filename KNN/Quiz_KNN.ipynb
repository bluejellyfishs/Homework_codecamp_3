# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#1

df = pd.read_csv('Wine.csv')
df
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# ...

# %%
#2

df.head(10)
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
# 5  1  14.39  1.87  2.45  14.6   96  2.50  2.52  0.30  1.98  5.25  1.02  3.58
# 6  1  14.06  2.15  2.61  17.6  121  2.60  2.51  0.31  1.25  5.05  1.06  3.58
# 7  1  14.83  1.64  2.17  14.0   97  2.80  2.98  0.29  1.98  5.20  1.08  2.85
# 8  1  13.86  1.35  2.27  16.0   98  2.98  3.15  0.22  1.85  7.22  1.01  3.55
# 9  1  14.10  2.16  2.30  18.0  105  2.95  3.32  0.22  2.38  5.75  1.25  3.17
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450
# 5  1290
# 6  1295
# 7  1045
# 8  1045
# 9  1510

# %%
df.tail(10)
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29       5.64  1.04  \
# 167  3  13.58  2.58  2.69  24.5  105  1.55  0.84  0.39  1.54   8.660000  0.74
# 168  3  13.40  4.60  2.86  25.0  112  1.98  0.96  0.27  1.11   8.500000  0.67
# 169  3  12.20  3.03  2.32  19.0   96  1.25  0.49  0.40  0.73   5.500000  0.66
# 170  3  12.77  2.39  2.28  19.5   86  1.39  0.51  0.48  0.64   9.899999  0.57
# 171  3  14.16  2.51  2.48  20.0   91  1.68  0.70  0.44  1.24   9.700000  0.62
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.700000  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.300000  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.200000  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.300000  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.200000  0.61
#
#      3.92  1065
# 167  1.80   750
# 168  1.92   630
# 169  1.83   510
# 170  1.63   470
# 171  1.71   660
# ...

# %%
df.sample(10)
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29      5.64  1.04  \
# 45   1  14.38  3.59  2.28  16.0  102  3.25  3.17  0.27  2.19  4.900000  1.04
# 170  3  12.77  2.39  2.28  19.5   86  1.39  0.51  0.48  0.64  9.899999  0.57
# 79   2  12.00  0.92  2.00  19.0   86  2.42  2.26  0.30  1.43  2.500000  1.38
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.320000  1.04
# 121  2  12.42  4.43  2.73  26.5  102  2.20  2.13  0.43  1.71  2.080000  0.92
# 85   2  12.16  1.61  2.31  22.8   90  1.78  1.69  0.43  1.56  2.450000  1.33
# 75   2  13.03  0.90  1.71  16.0   86  1.95  2.03  0.24  1.46  4.600000  1.19
# 27   1  13.87  1.90  2.80  19.4  107  2.95  2.97  0.37  1.76  4.500000  1.25
# 141  3  13.52  3.17  2.72  23.5   97  1.55  0.52  0.50  0.55  4.350000  0.89
# 156  3  12.45  3.03  2.64  27.0   97  1.90  0.58  0.63  1.14  7.500000  0.67
#
#      3.92  1065
# 45   3.44  1065
# 170  1.63   470
# 79   3.12   278
# 3    2.93   735
# 121  3.12   365
# 85   2.26   495
# ...

# %%
#3

fig = plt.figure(figsize=(12, 12))
sns.heatmap(df.isnull(), cbar=False, cmap='Accent')

# %%
#4

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1       177 non-null    int64
#  1   14.23   177 non-null    float64
#  2   1.71    177 non-null    float64
#  3   2.43    177 non-null    float64
#  4   15.6    177 non-null    float64
#  5   127     177 non-null    int64
#  6   2.8     177 non-null    float64
#  7   3.06    177 non-null    float64
#  8   .28     177 non-null    float64
#  9   2.29    177 non-null    float64
#  10  5.64    177 non-null    float64
#  11  1.04    177 non-null    float64
#  12  3.92    177 non-null    float64
#  13  1065    177 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.5 KB

# %%
df.describe()
# Out:
#                 1       14.23        1.71        2.43        15.6         127  \
# count  177.000000  177.000000  177.000000  177.000000  177.000000  177.000000
# mean     1.943503   12.993672    2.339887    2.366158   19.516949   99.587571
# std      0.773991    0.808808    1.119314    0.275080    3.336071   14.174018
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.360000    1.600000    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.870000    2.360000   19.500000   98.000000
# 75%      3.000000   13.670000    3.100000    2.560000   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#               2.8        3.06         .28        2.29        5.64        1.04  \
# count  177.000000  177.000000  177.000000  177.000000  177.000000  177.000000
# mean     2.292260    2.023446    0.362316    1.586949    5.054802    0.956983
# ...

# %%
#5

sns.pairplot(df)

# %%
#6

fig = plt.figure(figsize=(10, 10))
sns.distplot(df['1'])

# %%
fig = plt.figure(figsize=(10, 10))
sns.distplot(df['14.23'])

# %%
fig = plt.figure(figsize=(10, 10))
sns.distplot(df['1.71'])

# %%
fig = plt.figure(figsize=(10, 10))
sns.distplot(df['2.43'])

# %%
fig = plt.figure(figsize=(10, 10))
sns.distplot(df['15.6'])

# %%
fig = plt.figure(figsize=(10, 10))
sns.distplot(df['127'])

# %%
fig = plt.figure(figsize=(10, 10))
sns.distplot(df['2.8'])

# %%
fig = plt.figure(figsize=(10, 10))
sns.distplot(df['3.06'])

# %%
fig = plt.figure(figsize=(10, 10))
sns.distplot(df['.28'])

# %%
fig = plt.figure(figsize=(10, 10))
sns.distplot(df['2.29'])

# %%
fig = plt.figure(figsize=(10, 10))
sns.distplot(df['5.64'])

# %%
fig = plt.figure(figsize=(10, 10))
sns.distplot(df['1.04'])

# %%
fig = plt.figure(figsize=(10, 10))
sns.distplot(df['3.92'])

# %%
fig = plt.figure(figsize=(10, 10))
sns.distplot(df['1065'])

# %%
#7

fig = plt.figure(figsize=(12, 8))
sns.heatmap(df.corr())

# %%
#8

fig = plt.figure(figsize=(8,6))
sns.scatterplot(data=df,x='3.06',y='2.8')

# %%
#9

fig = plt.figure(figsize=(8,6))
sns.scatterplot(data=df,x='1',y='1065')

# %%
#10

plt.hist(df['1.04'])
plt.show()

# %%
#11

fig = plt.figure(figsize=(12, 8))
sns.boxplot(df['1.04'], orient='v')

# %%
fig = plt.figure(figsize=(12, 8))
sns.boxplot(df['1065'], orient='v')

# %%
#12

from sklearn.model_selection import train_test_split

X = df.drop('1', axis=1)
y = df['1']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# %%
#13

fig = plt.figure(figsize=(12, 8))
sns.scatterplot(x='1.04', y='2.8', data=df)

# %%
sns.countplot(x='1', data=df)

# %%
#14 

#ไม่ควรใช้ Standardization เพราะ feature ไม่ได้เป็น normal distribution

# %%
#15

from sklearn.preprocessing import MinMaxScaler

min_max_scaler = MinMaxScaler()

df_minmax = min_max_scaler.fit_transform(df.drop(['1'], axis=1))
df_minmax
# Out:
# array([[0.57105263, 0.2055336 , 0.4171123 , ..., 0.46341463, 0.78021978,
#         0.55064194],
#        [0.56052632, 0.3201581 , 0.70053476, ..., 0.44715447, 0.6959707 ,
#         0.64693295],
#        [0.87894737, 0.23913043, 0.60962567, ..., 0.30894309, 0.7985348 ,
#         0.85734665],
#        ...,
#        [0.58947368, 0.69960474, 0.48128342, ..., 0.08943089, 0.10622711,
#         0.39728959],
#        [0.56315789, 0.36561265, 0.54010695, ..., 0.09756098, 0.12820513,
#         0.40085592],
#        [0.81578947, 0.66403162, 0.73796791, ..., 0.10569106, 0.12087912,
#         0.20114123]])

# %%
new_df = pd.DataFrame(df_minmax, columns=df.columns[1:])
new_df
# Out:
#         14.23      1.71      2.43      15.6       127       2.8      3.06  \
# 0    0.571053  0.205534  0.417112  0.030928  0.326087  0.575862  0.510549
# 1    0.560526  0.320158  0.700535  0.412371  0.336957  0.627586  0.611814
# 2    0.878947  0.239130  0.609626  0.319588  0.467391  0.989655  0.664557
# 3    0.581579  0.365613  0.807487  0.536082  0.521739  0.627586  0.495781
# 4    0.834211  0.201581  0.582888  0.237113  0.456522  0.789655  0.643460
# ..        ...       ...       ...       ...       ...       ...       ...
# 172  0.705263  0.970356  0.582888  0.510309  0.271739  0.241379  0.056962
# 173  0.623684  0.626482  0.598930  0.639175  0.347826  0.282759  0.086498
# 174  0.589474  0.699605  0.481283  0.484536  0.543478  0.210345  0.073840
# 175  0.563158  0.365613  0.540107  0.484536  0.543478  0.231034  0.071730
# 176  0.815789  0.664032  0.737968  0.716495  0.282609  0.368966  0.088608
#
#           .28      2.29      5.64      1.04      3.92      1065
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(new_df, df['1'], test_size=0.3, random_state=70)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
predicted = knn.predict(X_test)

# %%
#16

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, predicted)
# Out:
# array([[21,  0,  0],
#        [ 1, 16,  1],
#        [ 0,  0, 15]])

# %%
print('Accuracy = ', accuracy_score(y_test, predicted))
print('F1 score = ', f1_score(y_test, predicted, average='micro'))
print('Precision = ', precision_score(y_test, predicted, average='micro'))
print('Recall = ', recall_score(y_test, predicted, average='micro'))
# Out:
# Accuracy =  0.9629629629629629
# F1 score =  0.9629629629629629
# Precision =  0.9629629629629629
# Recall =  0.9629629629629629

# %%
#17

accuracy_lst = []

for i in range(1, 30):
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(X_train, y_train)
    predicted_i = knn.predict(X_test)
    accuracy_lst.append(accuracy_score(y_test, predicted_i))
    
plt.figure(figsize=(10, 8))
plt.plot(range(1, 30), accuracy_lst, color='black', linestyle='dashed', marker='o',
        markerfacecolor='blue', markersize=7)
plt.xlabel('K')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
knn = KNeighborsClassifier(n_neighbors = 24)
knn.fit(X_train, y_train)
predicted = knn.predict(X_test)
confusion_matrix(y_test, predicted)
# Out:
# array([[21,  0,  0],
#        [ 1, 16,  1],
#        [ 0,  0, 15]])

# %%
print('Accuracy = ', accuracy_score(y_test, predicted))
# Out:
# Accuracy =  0.9629629629629629

# %%
#18

from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
predicted = knn.predict(X_test)

# %%
#19

accuracy_lst = []

for i in range(1, 50):
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(X_train, y_train)
    predicted_i = knn.predict(X_test)
    accuracy_lst.append(accuracy_score(y_test, predicted_i))
    
plt.figure(figsize=(10, 8))
plt.plot(range(1, 50), accuracy_lst, color='black', linestyle='dashed', marker='o',
        markerfacecolor='blue', markersize=7)
plt.xlabel('K')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
#20

X_train, X_test, y_train, y_test = train_test_split(new_df, df['1'], test_size=0.2, random_state=100)

from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
predicted = knn.predict(X_test)

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, predicted)

print('Accuracy = ', accuracy_score(y_test, predicted))
print('F1 score = ', f1_score(y_test, predicted, average='micro'))
print('Precision = ', precision_score(y_test, predicted, average='micro'))
print('Recall = ', recall_score(y_test, predicted, average='micro'))

accuracy_lst = []

for i in range(1, 30):
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(X_train, y_train)
    predicted_i = knn.predict(X_test)
    accuracy_lst.append(accuracy_score(y_test, predicted_i))
    
plt.figure(figsize=(10, 8))
plt.plot(range(1, 30), accuracy_lst, color='black', linestyle='dashed', marker='o',
        markerfacecolor='blue', markersize=7)
plt.xlabel('K')
plt.ylabel('Accuracy')
# Out:
# Accuracy =  0.8888888888888888
# F1 score =  0.8888888888888888
# Precision =  0.8888888888888888
# Recall =  0.8888888888888888
# Text(0, 0.5, 'Accuracy')

# %%
knn = KNeighborsClassifier(n_neighbors = 24)
knn.fit(X_train, y_train)
predicted = knn.predict(X_test)
confusion_matrix(y_test, predicted)
# Out:
# array([[ 9,  0,  0],
#        [ 0, 11,  0],
#        [ 0,  0, 16]])

# %%
print('Accuracy = ', accuracy_score(y_test, predicted))
# Out:
# Accuracy =  1.0
